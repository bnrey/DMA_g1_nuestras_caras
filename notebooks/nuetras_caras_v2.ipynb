# %% [markdown]
# Librerias necesarias

# %%
import os
import cv2
import numpy as np
import pandas as pd
from pathlib import Path
from typing import List, Tuple, Dict, Optional
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.spatial.distance import pdist, squareform
from scipy.spatial.distance import cdist
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error
import networkx as nx
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.manifold import Isomap

# %% [markdown]
# Funcion para detectar y recortar la cara

# %%
def detectar_cara(
    image_path: str,
    output_path: str,
    sin_caras_path: str,
    scale_factor: float = 1.1,
    min_neighbors: int = 5,
    color: bool = False,
    img_size: Optional[Tuple[int, int]] = None
) -> Optional[Tuple[int, int, int, int]]:
    """
    Detecta y guarda la cara más grande de una imagen, con redimensionado opcional.

    Args:
        image_path: Ruta de la imagen original
        output_path: Ruta donde se guarda la cara recortada
        sin_caras_path: Carpeta donde se guarda la imagen si no se detectan caras
        scale_factor: Parámetro para ajustar el escalado del detector
        min_neighbors: Cantidad mínima de vecinos para validar una detección
        color: Si True, guarda la cara en color; si False, en escala de grises
        img_size: Tamaño deseado para redimensionar la cara (ancho, alto)

    Returns:
        Coordenadas de la cara detectada, o None si no se detectó
    """
    img = cv2.imread(image_path)
    if img is None:
        print(f"[ERROR] No se pudo cargar la imagen: {image_path}")
        return None

    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    faces = face_cascade.detectMultiScale(gray, scaleFactor=scale_factor, minNeighbors = min_neighbors)

    if len(faces) == 0:
        print(f"[INFO] No se detectó ninguna cara en {image_path}")
        os.makedirs(sin_caras_path, exist_ok=True)
        no_face_path = os.path.join(sin_caras_path, os.path.basename(image_path))
        cv2.imwrite(no_face_path, img)
        print(f"[GUARDADO] Imagen sin cara: {no_face_path}")
        return None

    x, y, w, h = max(faces, key=lambda rect: rect[2] * rect[3])
    if w < 30 or h < 30:
        print(f"[INFO] Cara demasiado pequeña en {image_path}")
        return None

    face_crop = img[y:y+h, x:x+w] if color else gray[y:y+h, x:x+w]

    # Redimensionar si se indicó tamaño
    if img_size:
        face_crop = cv2.resize(face_crop, img_size)

    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    cv2.imwrite(output_path, face_crop)
    print(f"[GUARDADO] Cara guardada en: {output_path}")

    return (x, y, w, h)

# %%
def procesar_carpeta(
    input_folder,
    output_folder,
    sin_caras_folder,
    img_size: Optional[Tuple[int, int]] = None
):
    """
    Procesa todas las imágenes en subcarpetas del input_folder, detecta caras
    y las guarda redimensionadas en la estructura correspondiente.

    Args:
        input_folder: Carpeta con subcarpetas por persona
        output_folder: Carpeta destino de caras recortadas
        sin_caras_folder: Carpeta para imágenes donde no se detecta cara
        img_size: Tamaño deseado para redimensionar las caras (ancho, alto)
    """
    for subdir, _, files in os.walk(input_folder):
        if not files:
            continue

        persona = os.path.basename(subdir)
        output_subdir = os.path.join(output_folder, persona)
        os.makedirs(output_subdir, exist_ok=True)

        for file in files:
            if not file.lower().endswith(('.jpg', '.jpeg', '.png')):
                continue

            input_path = os.path.join(subdir, file)
            output_path = os.path.join(output_subdir, file)

            detectar_cara(
                image_path=input_path,
                output_path=output_path,
                sin_caras_path=sin_caras_folder,
                scale_factor=1.1,
                min_neighbors=5,
                color=False,
                img_size=img_size
            )

# %%
input_folder = '../data/crudas'
output_folder = '../data/procesadas'
sin_caras_folder = '../Eigenfaces/sin_caras'

# %%
# Por ejemplo, para guardar todo en 64x64
procesar_carpeta(input_folder, output_folder, sin_caras_folder, img_size=(64, 64))
# Out:
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\1742907850091.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\1742907850098.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\1742907850107.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\20250321_140317.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\20250321_140319.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\20250321_140321.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\AGUS_7605.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\AGUS_7606.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\AGUS_7607.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\AGUS_7608.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\AGUS_7609.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\AGUS_7610.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\AGUS_7611.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\AGUS_7612.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\AGUS_7613.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\AGUS_7614.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\AGUS_7615.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\AGUS_7616.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\IMG_1084.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\IMG_1085.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\IMG_1086.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\IMG_20250321_140715339.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\IMG_20250321_140716918_HDR.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\IMG_20250321_140718770_HDR.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\IMG_4174.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\IMG_4175.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\IMG_4176.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\IMG_6789.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\IMG_6790.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\IMG_6791.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\IMG_7609 2.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\IMG_7609.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\IMG_7613 2.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\IMG_8669.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\IMG_8670.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Agustin\IMG_8671.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\1742907849755.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\1742907849763.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\1742907849769.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\20250321_170439.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\20250321_170445.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\20250321_170448.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\ALE_7687.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\ALE_7688.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\ALE_7689.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\ALE_7690.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\ALE_7691.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\ALE_7692.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\ALE_7693.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\ALE_7694.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\ALE_7695.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\ALE_7696.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\IMG_1098.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\IMG_1099.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\IMG_1100.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\IMG_1285.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\IMG_1286.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\IMG_1287.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\IMG_20250321_170457147.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\IMG_20250321_170500203.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\IMG_20250321_170502353.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\IMG_4192.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\IMG_4193.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\IMG_4194.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\IMG_6820.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\IMG_6821.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\IMG_6822.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\IMG_7688 2.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\IMG_7688.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\IMG_7689 2.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\IMG_8688.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\IMG_8689.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Alejandro\IMG_8690.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\1742907849776.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\1742907849783.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\1742907849798.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\20250321_170423.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\20250321_170427.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\20250321_170432.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\CRISTIAN_7677.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\CRISTIAN_7678.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\CRISTIAN_7679.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\CRISTIAN_7680.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\CRISTIAN_7681.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\CRISTIAN_7682.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\CRISTIAN_7683.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\CRISTIAN_7684.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\CRISTIAN_7685.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\CRISTIAN_7686.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\IMG_1095.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\IMG_1096.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\IMG_1097.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\IMG_1282.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\IMG_1283.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\IMG_1284.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\IMG_20250321_170437206_HDR.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\IMG_20250321_170439519.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\IMG_20250321_170444007_HDR.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\IMG_4189.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\IMG_4190.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\IMG_4191.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\IMG_6817.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\IMG_6818.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\IMG_6819.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\IMG_7681 2.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\IMG_7681.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\IMG_7686 2.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\IMG_8685.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\IMG_8686.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Cristian\IMG_8687.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\1742907849853.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\1742907849861.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\1742907849868.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\20250321_140848.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\20250321_140850.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\20250321_140852.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\DANIEL_7666.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\DANIEL_7667.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\DANIEL_7668.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\DANIEL_7669.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\DANIEL_7670.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\DANIEL_7671.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\DANIEL_7672.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\DANIEL_7673.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\DANIEL_7674.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\IMG_1065.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\IMG_1066.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\IMG_1067.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\IMG_20250321_140511746.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\IMG_20250321_140514444.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\IMG_20250321_140517288.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\IMG_4167.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\IMG_4168.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\IMG_4169.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\IMG_6814.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\IMG_6815.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\IMG_6816.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\IMG_7667 2.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\IMG_7667.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\IMG_7668 2.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\IMG_8672.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\IMG_8673.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Daniel\IMG_8674.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\1742907849997.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\1742907850028.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\1742907850046.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\20250321_140307.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\20250321_140309.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\20250321_140311.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\FEDE_7597.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\FEDE_7598.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\FEDE_7599.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\FEDE_7600.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\FEDE_7601.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\FEDE_7602.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\FEDE_7603.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\FEDE_7604.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\IMG_1077.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\IMG_1078.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\IMG_1079.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\IMG_1252.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\IMG_1253.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\IMG_1254.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\IMG_4181.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\IMG_4182.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\IMG_4183.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\IMG_6795.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\IMG_6796.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\IMG_6797.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\IMG_7598 2.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\IMG_7598.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\IMG_7599 2.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\IMG_8666.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\IMG_8667.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Federico\IMG_8668.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\0B0181F5-4B8E-4457-B806-76ED18D03ECC_1_105_c.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\1742907849736.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\1742907849742.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\1742907849749.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\20250321_170523.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\20250321_170525.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\20250321_170526.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\BFDD433C-0C61-490B-B8C7-C4A06579E4D5_1_105_c.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\FBC2385B-C170-4DFF-8326-427CA84D31AE_1_105_c.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\GABI_7697.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\GABI_7698.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\GABI_7699.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\GABI_7700.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\GABI_7701.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\GABI_7702.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\GABI_7703.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\IMG_1101.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\IMG_1102.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\IMG_1103.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\IMG_1288.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\IMG_1289.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\IMG_1290.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\IMG_20250321_170531711.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\IMG_20250321_170533482.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\IMG_20250321_170535204.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\IMG_4195.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\IMG_4196.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\IMG_4197.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\IMG_6823.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\IMG_6824.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\IMG_6825.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\IMG_7699 2.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\IMG_7699.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\IMG_7700 2.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\IMG_8691.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\IMG_8692.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Gabriel\IMG_8693.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\1742907850056.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\1742907850066.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\1742907850076.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\20250321_140255.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\20250321_140258.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\20250321_140300.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\GUADA_7629.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\GUADA_7630.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\GUADA_7631.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\GUADA_7632.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\GUADA_7633.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\IMG_1080.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\IMG_1081.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\IMG_1082.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\IMG_1083.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\IMG_1249.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\IMG_1250.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\IMG_1251.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\IMG_20250321_140741716_HDR.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\IMG_20250321_140744163.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\IMG_20250321_140746141.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\IMG_6799.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\IMG_6800.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\IMG_6801.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\IMG_7630 2.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\IMG_7630.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\IMG_7632 2.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\IMG_8657.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\IMG_8658.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Guadalupe\IMG_8659.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\1742907849946.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\1742907849966.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\1742907849978.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\IMG_1062.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\IMG_1063.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\IMG_1064.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\IMG_1255.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\IMG_1256.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\IMG_1257.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\IMG_20250321_140522457.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\IMG_20250321_140524420_HDR.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\IMG_20250321_140526671.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\IMG_4170.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\IMG_4171.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\IMG_4172.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\IMG_6805.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\IMG_6806.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\IMG_6807.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\IMG_7647.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\IMG_7649 2.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\IMG_7649.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\IMG_8660.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\IMG_8661.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\IMG_8662.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\JOR_7646.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\JOR_7647.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\JOR_7648.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\JOR_7649.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\JOR_7650.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\JOR_7651.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\JOR_7652.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\JOR_7653.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jorgelina\JOR_7654.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\1742907850116.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\1742907850125.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\1742907850132.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\20250321_140325.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\20250321_140327.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\20250321_140328.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\CHINO_7617.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\CHINO_7618.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\CHINO_7619.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\CHINO_7620.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\CHINO_7621.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\CHINO_7622.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\CHINO_7623.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\CHINO_7624.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\CHINO_7625.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\CHINO_7626.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\CHINO_7627.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\CHINO_7628.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\IMG_1090.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\IMG_1091.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\IMG_1092.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\IMG_1246.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\IMG_1247.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\IMG_1248.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\IMG_20250321_140705033_HDR.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\IMG_20250321_140707409_HDR.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\IMG_20250321_140709919_HDR.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\IMG_4177.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\IMG_4178.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\IMG_4179.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\IMG_6792.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\IMG_6793.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\IMG_6794.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\IMG_7618.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\IMG_7619.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\IMG_7626.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\IMG_8663.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\IMG_8664.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Jose\IMG_8665.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Mauricio\20250321_140642.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Mauricio\20250321_140644.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Mauricio\20250321_140645.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Mauricio\IMG_1074.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Mauricio\IMG_1075.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Mauricio\IMG_1076.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Mauricio\IMG_1261.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Mauricio\IMG_1262.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Mauricio\IMG_1263.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Mauricio\IMG_20250321_140456357_HDR.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Mauricio\IMG_20250321_140502288_HDR.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Mauricio\IMG_20250321_140504119_HDR.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Mauricio\IMG_4158.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Mauricio\IMG_4159.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Mauricio\IMG_4160.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Mauricio\IMG_6808.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Mauricio\IMG_6809.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Mauricio\IMG_6810.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Mauricio\IMG_7634 2.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Mauricio\IMG_7635 2.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Mauricio\IMG_7635.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Mauricio\IMG_8653.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Mauricio\IMG_8654.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Mauricio\IMG_8655.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Mauricio\MAURI_7636.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\1742907849879.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\1742907849888.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\1742907849896.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\20250321_140633.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\20250321_140636.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\20250321_140638.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\IMG_1068.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\IMG_1069.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\IMG_1070.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\IMG_1258.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\IMG_1259.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\IMG_1260.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\IMG_20250321_140446409_HDR.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\IMG_20250321_140447827_HDR.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\IMG_20250321_140449310_HDR.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\IMG_4164.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\IMG_4165.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\IMG_4166.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\IMG_7639 2.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\IMG_7639.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\IMG_7640 2.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\IMG_8675.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\IMG_8676.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\IMG_8677.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\NATI_7639.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\NATI_7640.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\NATI_7641.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\NATI_7642.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\NATI_7643.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\NATI_7644.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Natalia\NATI_7645.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_M\1742907849811.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_M\1742907849823.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_M\1742907849847.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_M\20250321_140804.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_M\20250321_140807.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_M\20250321_140808.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_M\IMG_1071.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_M\IMG_1072.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_M\IMG_1073.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_M\IMG_1267.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_M\IMG_1268.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_M\IMG_1269.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_M\IMG_20250321_140533679_HDR.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_M\IMG_20250321_140535510_HDR.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_M\IMG_20250321_140537614_HDR.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_M\IMG_4161.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_M\IMG_4162.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_M\IMG_4163.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_M\IMG_6811.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_M\IMG_6812.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_M\IMG_6813.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\1742907849908.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\1742907849918.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\1742907849929.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\20250321_170637.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\20250321_170639.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\20250321_170641.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\IMG_1104.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\IMG_1105.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\IMG_1106.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\IMG_1264.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\IMG_1265.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\IMG_1266.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\IMG_20250321_140824265.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\IMG_20250321_170629085.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\IMG_20250321_170631563.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\IMG_20250321_170634292.jpg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\IMG_4184.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\IMG_4185.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\IMG_4186.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\IMG_6802.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\IMG_6803.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\IMG_6804.jpeg
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\IMG_7655 2.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\IMG_7655.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\IMG_7657.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\NOE_7655.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\NOE_7656.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\NOE_7657.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\NOE_7658.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\NOE_7659.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\NOE_7660.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\NOE_7661.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\NOE_7662.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\NOE_7663.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\NOE_7664.JPG
# [GUARDADO] Cara guardada en: ../data/procesadas\Noelia_R\NOE_7665.JPG

# %% [markdown]
# Cargar las caras y prepararlas para aplicar PCA

# %%
def cargar_dataset_con_labels(
    base_folder: str
) -> Tuple[np.ndarray, np.ndarray, Dict[str, int], np.ndarray]:
    """
    Carga imágenes desde subcarpetas (una por persona), ya redimensionadas y listas.

    Args:
        base_folder: Carpeta con subcarpetas por persona.

    Returns:
        X: np.ndarray con imágenes aplanadas (n_imágenes, ancho × alto)
        y: np.ndarray con etiquetas numéricas
        label_dict: dict {nombre_persona: clase_numérica}
        y_names: np.ndarray con los nombres de las personas
    """
    X = []
    y = []
    y_names = []
    label_dict = {}
    label_counter = 0
    base_path = Path(base_folder)

    for person_folder in base_path.iterdir():
        if not person_folder.is_dir():
            continue

        person_name = person_folder.name
        if person_name not in label_dict:
            label_dict[person_name] = label_counter
            label_counter += 1

        for img_file in person_folder.iterdir():
            if img_file.suffix.lower() not in {'.jpg', '.jpeg', '.png'}:
                continue

            img = cv2.imread(str(img_file), cv2.IMREAD_GRAYSCALE)
            if img is None:
                print(f"[WARNING] No se pudo leer {img_file}")
                continue

            X.append(img.flatten())
            y.append(label_dict[person_name])
            y_names.append(person_name)

    X = np.array(X)
    y = np.array(y)
    y_names = np.array(y_names)

    print(f"[INFO] Se cargaron {X.shape[0]} imágenes de {len(label_dict)} personas.")
    return X, y, label_dict, y_names

# %%
def mostrar_imagenes_aleatorias_auto(X, y_names, n=6, seed=42):
    """
    Muestra n imágenes aleatorias con sus etiquetas, detectando automáticamente el tamaño.

    Args:
        X: matriz de imágenes aplanadas (n_muestras, n_pixeles)
        y_names: lista de nombres por imagen
        n: cantidad de imágenes a mostrar
        seed: semilla para reproducibilidad
    """
    # Detectar tamaño de imagen cuadrada automáticamente
    total_pixeles = X.shape[1]
    lado = int(np.sqrt(total_pixeles))
    
    if lado * lado != total_pixeles:
        print(f"[ERROR] Las imágenes no parecen cuadradas: {total_pixeles} pixeles no forman un cuadrado perfecto.")
        return

    np.random.seed(seed)
    indices = np.random.choice(len(X), size=n, replace=False)

    plt.figure(figsize=(15, 3))
    for i, idx in enumerate(indices):
        img = X[idx].reshape((lado, lado))
        plt.subplot(1, n, i + 1)
        plt.imshow(img, cmap='gray')
        plt.title(y_names[idx])
        plt.axis('off')
    plt.suptitle(f"{n} imágenes aleatorias del dataset", fontsize=14)
    plt.tight_layout()
    plt.show()

# %%
X, y, label_dict, y_names = cargar_dataset_con_labels(output_folder)
# Out:
# [INFO] Se cargaron 427 imágenes de 13 personas.

# %%
# Out:
# [68 77 65 ... 35 22 16]

# %%
mostrar_imagenes_aleatorias_auto(X, y_names, n = 10, seed = 2)

# %% [markdown]
# Cara promedio

# %%
mean_face = np.mean(X, axis = 0)

# Convertir a imagen 2D
mean_face_image = mean_face.reshape(64, 64)

# Visualizar la cara promedio
plt.figure(figsize=(6, 6))
plt.imshow(mean_face_image, cmap='gray')
plt.title("Cara Promedio")
plt.axis('off')
plt.show()

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components = 0.95)  # Mantener el 85% de la varianza
X_pca = pca.fit_transform(X_scaled)

print(f"[INFO] Se redujo la dimensionalidad de {X.shape[1]} a {X_pca.shape[1]} componentes principales.")
# Out:
# [INFO] Se redujo la dimensionalidad de 4096 a 215 componentes principales.

# %% [markdown]
# Grafico de la varianza explicada

# %%
#Varianza explicada
plt.figure(figsize=(10, 5))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.title('Varianza explicada acumulativa por PCA')
plt.xlabel('Número de componentes')
plt.ylabel('Varianza explicada acumulativa')
plt.grid()
plt.show()

# %% [markdown]
# Mostrar componentes principales elegidas

# %%
def mostrar_componentes(pca, componentes_idx, img_size=(64, 64)):
    """
    Muestra las componentes principales específicas indicadas por el usuario.

    Args:
        pca: objeto PCA ya ajustado
        componentes_idx: lista de índices de componentes (por ejemplo [0, 4, 10])
        img_size: tamaño (ancho, alto) de las imágenes originales
    """
    n = len(componentes_idx)
    rows = 2
    cols = (n + 1) // rows

    fig, axes = plt.subplots(rows, cols, figsize=(15, 6))
    axes = axes.flatten()

    for i, idx in enumerate(componentes_idx):
        comp = pca.components_[idx]
        ax = axes[i]
        ax.imshow(comp.reshape(img_size), cmap='gray')
        var_exp = pca.explained_variance_ratio_[idx] * 100
        ax.set_title(f"Comp {idx + 1} ({var_exp:.2f}% var)")
        ax.axis('off')

    for ax in axes[n:]:
        ax.axis('off')

    plt.suptitle("Componentes específicas seleccionadas", fontsize=14)
    plt.tight_layout()
    plt.show()

# %%
# Mostrar las componentes 
componentes_a_mostrar = [0, 1, 2]
mostrar_componentes(pca, componentes_a_mostrar, img_size=(64, 64))

# %%
def mostrar_componentes_principales(pca, n=5, ultimas=False, img_size=(64, 64)):
    """
    Muestra las primeras o últimas n componentes principales del PCA.

    Args:
        pca: objeto PCA ya ajustado
        n: número de componentes a mostrar
        ultimas: si True, muestra las últimas n en lugar de las primeras
        img_size: tamaño para reconstruir las imágenes (ancho, alto)
    """
    total = pca.components_.shape[0]
    if ultimas:
        componentes = pca.components_[-n:]
        indices = list(range(total - n + 1, total + 1))
        titulo = f"Últimas {n} Componentes Principales"
    else:
        componentes = pca.components_[:n]
        indices = list(range(1, n + 1))
        titulo = f"Primeras {n} Componentes Principales"

    rows = 2
    cols = (n + 1) // rows
    fig, axes = plt.subplots(rows, cols, figsize=(15, 8))
    axes = axes.flatten()
    for i in range(n):
        ax = axes[i]
        ax.imshow(componentes[i].reshape(img_size), cmap='gray')
        ax.set_title(f"Componente {indices[i]}")
        ax.axis('off')
    for ax in axes[n:]:
        ax.axis('off')
    plt.suptitle(titulo, fontsize=14)
    plt.tight_layout()
    plt.show()

# %%
# Mostrar las primeras 5
mostrar_componentes_principales(pca, n=5, ultimas=False)

# Mostrar las últimas 5
mostrar_componentes_principales(pca, n=5, ultimas=True)

# %% [markdown]
# Reconstruir imagenes con PCA

# %%
def reconstruir_desde_pca(X_pca, pca, scaler):
    """
    Reconstruye las imágenes originales a partir de sus representaciones PCA.

    Args:
        X_pca: matriz reducida (output de pca.transform)
        pca: objeto PCA entrenado
        scaler: objeto StandardScaler entrenado

    Returns:
        X_reconstruida: matriz reconstruida (con forma y escala original)
    """
    # 1. Volver al espacio estandarizado
    X_estandarizado = pca.inverse_transform(X_pca)
    
    # 2. Deshacer la estandarización
    X_reconstruida = scaler.inverse_transform(X_estandarizado)
    
    return X_reconstruida

# %%
X_reconstruida = reconstruir_desde_pca(X_pca, pca, scaler)

# %%
plt.imshow(X_reconstruida[0].reshape((64, 64)), cmap='gray')

# %%
def mostrar_reconstrucciones(
    X, X_pca, pca, scaler,
    indices=None, n=10, aleatorio=False,
    img_size=(64, 64), seed=42
):
    """
    Muestra imágenes originales y sus reconstrucciones desde PCA, con MSE.

    Args:
        X: matriz original (no escalada)
        X_pca: matriz reducida (salida de pca.transform)
        pca: objeto PCA entrenado
        scaler: objeto StandardScaler usado para escalar X
        indices: lista opcional de índices de imágenes a mostrar
        n: cantidad de imágenes a mostrar (si no se pasan índices)
        aleatorio: si True, elige n imágenes al azar
        img_size: tamaño original de las imágenes
        seed: para reproducibilidad cuando aleatorio=True
    """
    # Reconstrucción completa
    X_pca_inv = pca.inverse_transform(X_pca)
    X_reconstruido = scaler.inverse_transform(X_pca_inv)

    # Seleccionar índices
    total = X.shape[0]
    if indices is not None:
        selected_idx = indices
    elif aleatorio:
        np.random.seed(seed)
        selected_idx = np.random.choice(total, size=n, replace=False)
    else:
        selected_idx = np.arange(n)

    plt.figure(figsize=(15, 4))
    for i, idx in enumerate(selected_idx):
        original = X[idx].reshape(img_size)
        reconstruida = X_reconstruido[idx].reshape(img_size)
        mse = mean_squared_error(original, reconstruida)

        # Original
        plt.subplot(2, len(selected_idx), i + 1)
        plt.imshow(original, cmap='gray')
        plt.title(f"Original {idx}")
        plt.axis('off')

        # Reconstrucción
        plt.subplot(2, len(selected_idx), i + 1 + len(selected_idx))
        plt.imshow(reconstruida, cmap='gray')
        plt.title(f"Rec {idx}\nMSE: {mse:.2f}")
        plt.axis('off')

    plt.suptitle("Reconstrucción con PCA (con error MSE)", fontsize=14)
    plt.tight_layout()
    plt.show()

# %%
mostrar_reconstrucciones(X, X_pca, pca, scaler, aleatorio=True, n=8, img_size=(64, 64))

# %%
def analizar_similitudes(X, y, y_names):
    dist_matrix = cdist(X, X, metric="euclidean")

    resultados = []
    error_total = 0
    self_matches = 0
    aciertos_con_otro_ejemplar = 0

    for i in range(len(X)):
        distancias = dist_matrix[i].copy()
        distancias[i] = np.inf  # ignorar comparación consigo misma
        j = np.argmin(distancias)

        mismo_label = y[i] == y[j]
        misma_imagen = j == i

        if mismo_label and not misma_imagen:
            aciertos_con_otro_ejemplar += 1
        elif not mismo_label:
            error_total += 1
        elif misma_imagen:
            self_matches += 1

        resultados.append({
            "indice": i,
            "indice_mas_parecido": j,
            "persona": y_names[i],
            "persona_parecida": y_names[j],
            "es_igual": mismo_label,
            "distancia": distancias[j],
            "igual_a_si_misma": misma_imagen
})

    df_resultados = pd.DataFrame(resultados)

    total = len(X)
    tasa_error = error_total / total
    tasa_correctos_otros = aciertos_con_otro_ejemplar / total
    tasa_self_match = self_matches / total

    resumen = {
        "Total imágenes": total,
        "Errores (distinta persona)": error_total,
        "Aciertos (misma persona, otra imagen)": aciertos_con_otro_ejemplar,
        "Coincidencias consigo misma (raro)": self_matches,
        "Tasa de error": tasa_error,
        "Tasa de acierto con otro ejemplar": tasa_correctos_otros
    }

    return df_resultados, resumen

# %%
df_pca, info_pca = analizar_similitudes(X_pca, y, y_names)
df_x, info_x = analizar_similitudes(X, y, y_names)

# %%
df_x[df_x["es_igual"] == False].sort_values("distancia", ascending=True)
# Out:
#      indice  indice_mas_parecido    persona persona_parecida  es_igual  \
# 39       39                    7  Alejandro          Agustin     False
# 60       60                   14  Alejandro          Agustin     False
# 135     135                   35     Daniel          Agustin     False
# 369     369                  270    Natalia        Jorgelina     False
# 362     362                   59    Natalia        Alejandro     False
# 37       37                    1  Alejandro          Agustin     False
# 130     130                   85     Daniel         Cristian     False
#
#        distancia  igual_a_si_misma
# 39   2446.475015             False
# 60   2537.621130             False
# 135  2603.699483             False
# 369  2905.891946             False
# 362  2946.267639             False
# 37   3066.125894             False
# 130  3241.434867             False

# %%
df_pca[df_pca["es_igual"] == False].sort_values("distancia", ascending=True)
# Out:
#      indice  indice_mas_parecido    persona persona_parecida  es_igual  \
# 61       61                  107  Alejandro         Cristian     False
# 126     126                  158     Daniel         Federico     False
# 123     123                   16     Daniel          Agustin     False
# 2         2                   38    Agustin        Alejandro     False
# 60       60                   32  Alejandro          Agustin     False
# 241     241                   13  Guadalupe          Agustin     False
# 135     135                   35     Daniel          Agustin     False
# 115     115                  409     Daniel         Noelia_R     False
# 312     312                  174       Jose         Federico     False
# 369     369                  158    Natalia         Federico     False
# 37       37                    1  Alejandro          Agustin     False
# 130     130                   85     Daniel         Cristian     False
#
#      distancia  igual_a_si_misma
# 61   50.405898             False
# 126  52.542377             False
# 123  53.144927             False
# 2    53.447307             False
# 60   54.073951             False
# 241  56.973121             False
# 135  59.874342             False
# 115  59.919545             False
# 312  64.803905             False
# 369  67.654295             False
# 37   69.626686             False
# 130  75.834440             False

# %%
def visualizar_errores_desde_df(X, df_resultados, img_size=(64, 64)):
    errores = df_resultados[df_resultados["es_igual"] == False]
    total_errores = len(errores)

    if total_errores == 0:
        print("✅ No hay errores que mostrar.")
        return

    ncols = 5  # columnas por fila
    nrows = 2 * int(np.ceil(total_errores / ncols))  # 2 filas por grupo de ncols

    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(3 * ncols, 3 * nrows))
    axes = np.array(axes).reshape(nrows, ncols)  # asegurar forma 2D

    for i, row in enumerate(errores.itertuples()):
        idx_real = row.indice
        idx_parecido = row.indice_mas_parecido
        nombre_real = row.persona
        nombre_parecido = row.persona_parecida
        dist = row.distancia

        col = i % ncols
        fila_real = (i // ncols) * 2
        fila_parecida = fila_real + 1

        # Imagen real
        axes[fila_real, col].imshow(X[idx_real].reshape(img_size), cmap='gray')
        axes[fila_real, col].set_title(f"Persona: {nombre_real}")
        axes[fila_real, col].axis("off")

        # Imagen parecida
        axes[fila_parecida, col].imshow(X[idx_parecido].reshape(img_size), cmap='gray')
        axes[fila_parecida, col].set_title(f"Confundida con: {nombre_parecido}\nDist: {dist:.2f}")
        axes[fila_parecida, col].axis("off")

    plt.suptitle("Caras confundidas — Persona (arriba) vs Más parecida (abajo)", fontsize=16)
    plt.tight_layout()
    plt.show()

# %%
visualizar_errores_desde_df(X, df_pca, img_size=(64, 64))

# %%
# --- DISTANCIAS EN X (original)
dist_X = cdist(X, X, metric='euclidean')
np.fill_diagonal(dist_X, np.inf)  # evitar que se elijan a sí mismas
pred_X = np.argmin(dist_X, axis=1)
acierto_X = y == y[pred_X]

# --- DISTANCIAS EN X_pca (reducido)
dist_PCA = cdist(X_pca, X_pca, metric='euclidean')
np.fill_diagonal(dist_PCA, np.inf)
pred_PCA = np.argmin(dist_PCA, axis=1)
acierto_PCA = y == y[pred_PCA]

# --- Comparación general
total = len(X)
print("🔍 Comparación general:")
print(f"Aciertos con X: {acierto_X.sum()} / {total}")
print(f"Aciertos con X_pca: {acierto_PCA.sum()} / {total}")

# --- ¿Dónde cambian las predicciones?
cambios = pred_X != pred_PCA
print(f"\n⚠️ Cambios en {cambios.sum()} casos.")

# --- ¿Dónde X acierta y PCA falla?
x_bien_pca_mal = acierto_X & ~acierto_PCA
print(f"✔️ X bien / PCA mal: {x_bien_pca_mal.sum()} casos")

# --- ¿Dónde PCA acierta y X falla?
x_mal_pca_bien = ~acierto_X & acierto_PCA
print(f"✔️ PCA bien / X mal: {x_mal_pca_bien.sum()} casos")

# --- DataFrame para inspección posterior
comparacion = pd.DataFrame({
    "indice": np.arange(total),
    "real": y,
    "pred_X": y[pred_X],
    "pred_PCA": y[pred_PCA],
    "match_X": acierto_X,
    "match_PCA": acierto_PCA,
    "cambio": cambios
})
# Out:
# 🔍 Comparación general:
# Aciertos con X: 420 / 427
# Aciertos con X_pca: 415 / 427
#
# ⚠️ Cambios en 105 casos.
# ✔️ X bien / PCA mal: 7 casos
# ✔️ PCA bien / X mal: 2 casos

# %%
comparacion[~comparacion["match_PCA"] & comparacion["match_X"]]
# Out:
#      indice  real  pred_X  pred_PCA  match_X  match_PCA  cambio
# 68       68     2       2        11     True      False    True
# 163     163     5       5         9     True      False    True
# 183     183     5       5        11     True      False    True
# 187     187     5       5         8     True      False    True
# 275     275     9       9        13     True      False    True
# 370     370    12      12         9     True      False    True
# 406     406    13      13        10     True      False    True

# %%
# Elegí tus índices, por ejemplo los 10 primeros casos donde X acierta y PCA falla
casos = comparacion.query("match_X == True and match_PCA == False").head(10)
indices = casos["indice"].values

fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(15, 6))

for ax, idx in zip(axes.flatten(), indices):
    ax.imshow(X[idx].reshape(64, 64), cmap='gray')
    ax.set_title(f"Idx {idx}\nReal: {y_names[idx]}\nPCA Pred: {y_names[pred_PCA[idx]]}")
    ax.axis('off')

plt.suptitle("Casos donde X acierta y PCA falla", fontsize=16)
plt.tight_layout()
plt.show()

# %%
comparacion[comparacion["match_PCA"] == False]
# Out:
#      indice  real  pred_X  pred_PCA  match_X  match_PCA  cambio
# 68       68     2       2        11     True      False    True
# 163     163     5       5         9     True      False    True
# 170     170     5      10        10    False      False   False
# 179     179     5       9         9    False      False   False
# 183     183     5       5        11     True      False    True
# 187     187     5       5         8     True      False    True
# 216     216     7       0        11    False      False    True
# 275     275     9       9        13     True      False    True
# 370     370    12      12         9     True      False    True
# 406     406    13      13        10     True      False    True
# 421     421    13       9         9    False      False   False
# 423     423    13       9         9    False      False    True

# %% [markdown]
# OPCION 2 ISOMAP

# %%
isomap = Isomap(n_neighbors=5, n_components=50)
X_iso = isomap.fit_transform(X_scaled)
# Out:
# c:\Users\Guadalupe\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_isomap.py:384: UserWarning: The number of connected components of the neighbors graph is 3 > 1. Completing the graph to fit Isomap might be slow. Increase the number of neighbors to avoid this issue.
#   self._fit_transform(X)
# c:\Users\Guadalupe\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# c:\Users\Guadalupe\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# c:\Users\Guadalupe\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])

# %%
def top_parejas_mas_parecidas_entre_personas(X, y, y_names, top_n=5):
    """
    Muestra las N parejas de imágenes más parecidas entre personas distintas.

    Args:
        X: matriz de imágenes aplanadas
        y: etiquetas numéricas
        y_names: nombres de personas
        top_n: cuántas parejas mostrar
    """
    total_pixeles = X.shape[1]
    lado = int(np.sqrt(total_pixeles))

    if lado * lado != total_pixeles:
        print("[ERROR] Las imágenes no son cuadradas.")
        return

    # Calcular matriz de distancias
    dist_matrix = squareform(pdist(X, metric='euclidean'))
    np.fill_diagonal(dist_matrix, np.inf)

    # Enmascarar comparaciones entre la misma persona
    mask = np.equal.outer(y, y)
    dist_matrix[mask] = np.inf

    # Obtener los índices de las N distancias más bajas
    indices = np.dstack(np.unravel_index(np.argsort(dist_matrix, axis=None), dist_matrix.shape))[0]

    # Filtrar duplicados simétricos (i, j) y (j, i)
    pares_vistos = set()
    top_pares = []
    for i, j in indices:
        if (j, i) in pares_vistos or y[i] == y[j]:
            continue
        pares_vistos.add((i, j))
        top_pares.append((i, j, dist_matrix[i, j]))
        if len(top_pares) == top_n:
            break

    # Mostrar los pares
    for k, (i, j, dist) in enumerate(top_pares, 1):
        print(f"\n🔹 Pareja #{k}:")
        print(f"🧍 {y_names[i]} (idx {i})  vs  🧍 {y_names[j]} (idx {j})")
        print(f"📏 Distancia: {dist:.2f}")

        # Mostrar lado a lado
        plt.figure(figsize=(4, 2))
        for idx, pos in enumerate([i, j]):
            img = X[pos].reshape((lado, lado))
            plt.subplot(1, 2, idx + 1)
            plt.imshow(img, cmap='gray')
            plt.title(f"{y_names[pos]} (idx {pos})")
            plt.axis('off')
        plt.suptitle(f"Pareja #{k}: Caras más parecidas entre personas")
        plt.tight_layout()
        plt.show()

# %%
top_parejas_mas_parecidas_entre_personas(X, y, y_names, top_n=5)
# Out:
# 🔹 Pareja #1:
# 🧍 Cristian (idx 305)  vs  🧍 Agustín (idx 279)
# 📏 Distancia: 2107.88
# 🔹 Pareja #2:
# 🧍 Federico (idx 335)  vs  🧍 Agustín (idx 279)
# 📏 Distancia: 2112.73
# 🔹 Pareja #3:
# 🧍 Federico (idx 335)  vs  🧍 Agustín (idx 289)
# 📏 Distancia: 2203.65
# 🔹 Pareja #4:
# 🧍 Agustín (idx 270)  vs  🧍 Federico (idx 341)
# 📏 Distancia: 2218.14
# 🔹 Pareja #5:
# 🧍 Guadalupe (idx 368)  vs  🧍 Agustín (idx 285)
# 📏 Distancia: 2219.04

# %% [markdown]
# Cara promedio por persona.

# %%
# Invertir el dict para obtener nombre por clase
inv_label_dict = {v: k for k, v in label_dict.items()}

# Crear cara promedio por persona
caras_por_persona = {}
for clase in np.unique(y):
    indices = np.where(y == clase)[0]
    X_persona = X[indices]
    cara_promedio = np.mean(X_persona, axis=0)
    nombre = inv_label_dict[clase]
    caras_por_persona[nombre] = cara_promedio

# Convertimos las caras promedio a una matriz
nombres = list(caras_por_persona.keys())
X_avg = np.array([caras_por_persona[n] for n in nombres])

# Distancia euclidiana (o cosine)
dist_matrix = squareform(pdist(X_avg, metric='euclidean'))

# %%
np.fill_diagonal(dist_matrix, np.inf)  # Evitar compararse a sí mismo

i, j = np.unravel_index(np.argmin(dist_matrix), dist_matrix.shape)
print(f"👥 Las personas más parecidas son: {nombres[i]} y {nombres[j]}")
print(f"🔍 Distancia entre sus caras promedio: {dist_matrix[i, j]:.2f}")
# Out:
# 👥 Las personas más parecidas son: Mauricio y Daniel
# 🔍 Distancia entre sus caras promedio: 1296.10

# %%
def mostrar_caras_promedio(X_avg, nombres, indices, img_size=(64, 64)):
    i, j = indices
    plt.figure(figsize=(6, 3))
    for idx, pos in enumerate([i, j]):
        cara = X_avg[pos].reshape(img_size)
        plt.subplot(1, 2, idx + 1)
        plt.imshow(cara, cmap='gray')
        plt.title(nombres[pos])
        plt.axis('off')
    plt.suptitle("Caras promedio más parecidas")
    plt.tight_layout()
    plt.show()

mostrar_caras_promedio(X_avg, nombres, (i, j), img_size=(64, 64))

# %%
def ranking_similitud_entre_personas(dist_matrix: np.ndarray, nombres: list, top_n: int = 3):
    """
    Muestra un ranking de personas más parecidas a cada una, usando sus caras promedio.

    Args:
        dist_matrix: matriz de distancias entre caras promedio (con np.inf en la diagonal)
        nombres: lista de nombres en el mismo orden que la matriz
        top_n: cantidad de personas más parecidas a mostrar
    """
    for i, nombre in enumerate(nombres):
        # Ordenamos las distancias (excepto a sí mismo)
        indices_ordenados = np.argsort(dist_matrix[i])
        similares = [(nombres[j], dist_matrix[i, j]) for j in indices_ordenados[:top_n]]

        print(f"\n👤 {nombre} se parece más a:")
        for j, (otro_nombre, dist) in enumerate(similares, start=1):
            print(f"   {j}. {otro_nombre} (distancia = {dist:.2f})")

# %%
# Asumiendo que ya hiciste:
# X_avg: matriz con caras promedio
# nombres: lista con nombres de personas
# dist_matrix: matriz de distancias entre personas

ranking_similitud_entre_personas(dist_matrix, nombres, top_n=5)
# Out:
# 👤 Jorgelina se parece más a:
#    1. Natalia (distancia = 1484.01)
#    2. Agustín (distancia = 1518.01)
#    3. Alejandro (distancia = 1572.45)
#    4. Daniel (distancia = 1759.18)
#    5. Noelia_R (distancia = 1765.20)
#
# 👤 Noelia_M se parece más a:
#    1. Federico (distancia = 1801.39)
#    2. Noelia_R (distancia = 1923.76)
#    3. Daniel (distancia = 1984.78)
#    4. Mauricio (distancia = 2013.26)
#    5. José (distancia = 2161.23)
#
# 👤 José se parece más a:
#    1. Daniel (distancia = 1557.37)
#    2. Mauricio (distancia = 1664.38)
#    3. Federico (distancia = 1688.89)
#    4. Noelia_R (distancia = 1951.57)
#    5. Agustín (distancia = 2002.02)
#
# 👤 Gabriel se parece más a:
#    1. Cristian (distancia = 2370.21)
#    2. Daniel (distancia = 2409.51)
#    3. Agustín (distancia = 2534.37)
#    4. Noelia_R (distancia = 2613.52)
#    5. Mauricio (distancia = 2723.90)
#
# 👤 Mauricio se parece más a:
#    1. Daniel (distancia = 1347.46)
#    2. Noelia_R (distancia = 1558.22)
#    3. Agustín (distancia = 1659.84)
#    4. José (distancia = 1664.38)
#    5. Federico (distancia = 1665.14)
#
# 👤 Daniel se parece más a:
#    1. Mauricio (distancia = 1347.46)
#    2. Agustín (distancia = 1470.73)
#    3. Noelia_R (distancia = 1512.65)
#    4. José (distancia = 1557.37)
#    5. Federico (distancia = 1611.46)
#
# 👤 Natalia se parece más a:
#    1. Jorgelina (distancia = 1484.01)
#    2. Noelia_R (distancia = 1715.33)
#    3. Alejandro (distancia = 1769.31)
#    4. Mauricio (distancia = 1784.82)
#    5. Agustín (distancia = 1795.64)
#
# 👤 Noelia_R se parece más a:
#    1. Daniel (distancia = 1512.65)
#    2. Mauricio (distancia = 1558.22)
#    3. Natalia (distancia = 1715.33)
#    4. Jorgelina (distancia = 1765.20)
#    5. Agustín (distancia = 1819.81)
#
# 👤 Agustín se parece más a:
#    1. Daniel (distancia = 1470.73)
#    2. Jorgelina (distancia = 1518.01)
#    3. Alejandro (distancia = 1532.81)
#    4. Mauricio (distancia = 1659.84)
#    5. Natalia (distancia = 1795.64)
#
# 👤 Cristian se parece más a:
#    1. Alejandro (distancia = 1533.60)
#    2. Agustín (distancia = 1896.87)
#    3. Jorgelina (distancia = 1947.51)
#    4. Natalia (distancia = 2023.94)
#    5. Daniel (distancia = 2091.94)
#
# 👤 Federico se parece más a:
#    1. Daniel (distancia = 1611.46)
#    2. Mauricio (distancia = 1665.14)
#    3. José (distancia = 1688.89)
#    4. Noelia_M (distancia = 1801.39)
#    5. Noelia_R (distancia = 2031.69)
#
# 👤 Guadalupe se parece más a:
#    1. Natalia (distancia = 1908.92)
#    2. Agustín (distancia = 1932.42)
#    3. Noelia_R (distancia = 1982.01)
#    4. Mauricio (distancia = 2032.70)
#    5. Jorgelina (distancia = 2117.73)
#
# 👤 Alejandro se parece más a:
#    1. Agustín (distancia = 1532.81)
#    2. Cristian (distancia = 1533.60)
#    3. Jorgelina (distancia = 1572.45)
#    4. Natalia (distancia = 1769.31)
#    5. Mauricio (distancia = 1990.56)

# %%
def top_pares_mas_parecidos(dist_matrix: np.ndarray, nombres: list, top_n: int = 10):
    """
    Calcula el top N de pares de personas más parecidas entre sí.

    Args:
        dist_matrix: matriz simétrica de distancias (NxN)
        nombres: lista de nombres en el mismo orden que la matriz
        top_n: cantidad de pares más similares a mostrar

    Returns:
        DataFrame con columnas: Persona A, Persona B, Distancia
    """
    n = len(nombres)
    pares = []

    for i in range(n):
        for j in range(i + 1, n):  # solo pares únicos (sin repetir ni comparar consigo mismo)
            pares.append((nombres[i], nombres[j], dist_matrix[i, j]))

    # Ordenar por distancia
    pares_ordenados = sorted(pares, key=lambda x: x[2])

    # Convertir a DataFrame
    df_top = pd.DataFrame(pares_ordenados[:top_n], columns=["Persona A", "Persona B", "Distancia"])
    return df_top

# %%
df_top10 = top_pares_mas_parecidos(dist_matrix, nombres, top_n=10)
print(df_top10)
# Out:
#    Persona A  Persona B    Distancia
# 0   Mauricio     Daniel  1296.103787
# 1     Daniel   Noelia_R  1388.889493
# 2  Jorgelina    Natalia  1398.015483
# 3   Cristian  Alejandro  1403.592383
# 4     Daniel    Agustín  1468.900524
# 5   Mauricio   Noelia_R  1477.356186
# 6  Jorgelina  Alejandro  1512.933033
# 7  Jorgelina    Agustín  1527.862136
# 8    Agustín  Alejandro  1578.920642
# 9   Mauricio    Agustín  1581.090757

# %%
def grafo_similitud(dist_matrix, nombres, top_n=1):
    G = nx.Graph()

    # Agregar nodos
    for name in nombres:
        G.add_node(name)

    # Agregar aristas con top_n más parecidos
    for i, name in enumerate(nombres):
        vecinos = np.argsort(dist_matrix[i])[:top_n]
        for j in vecinos:
            if i != j:
                G.add_edge(name, nombres[j], weight=round(dist_matrix[i, j], 2))

    # Dibujar grafo
    pos = nx.spring_layout(G, seed=42)
    plt.figure(figsize=(10, 8))
    nx.draw(G, pos, with_labels=True, node_size=2000, node_color='lightblue', font_size=10, font_weight='bold')
    labels = nx.get_edge_attributes(G, 'weight')
    nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
    plt.title("Grafo de similitud entre personas (caras promedio)")
    plt.show()

# %%
grafo_similitud(dist_matrix, nombres, top_n=1)  # o top_n=3 para más conexiones

# %%
# Crear grafo
G = nx.Graph()

# Agregar nodos y aristas con pesos
for p1, p2, dist in similar_pairs:
    G.add_edge(p1, p2, weight=dist)

# Posiciones para los nodos
pos = nx.spring_layout(G, seed=42)

# Dibujar nodos y etiquetas
plt.figure(figsize=(10, 8))
nx.draw_networkx_nodes(G, pos, node_color='skyblue', node_size=1500)
nx.draw_networkx_labels(G, pos, font_size=10, font_weight='bold')

# Dibujar aristas con pesos como etiquetas
edges = G.edges(data=True)
nx.draw_networkx_edges(G, pos, edgelist=edges)
edge_labels = {(u, v): f"{d['weight']:.0f}" for u, v, d in edges}
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=9)

plt.title("Red de Similitud entre Personas (Distancia entre Caras Promedio)")
plt.axis('off')
plt.tight_layout()
plt.show()

# %%
def dendrograma_similitud(X_avg, nombres):
    linked = linkage(X_avg, method='ward')  # podés probar 'average' también

    plt.figure(figsize=(10, 6))
    dendrogram(linked, labels=nombres, orientation='right', leaf_font_size=10)
    plt.title("Dendrograma de similitud entre caras promedio")
    plt.tight_layout()
    plt.show()

# %%
dendrograma_similitud(X_avg, nombres)

# %%
# Out:
# X.shape = (293, 4096)
# ¿Hay NaN en X_scaled? False
# ¿Hay Inf en X_scaled? False

# %%
def visualizar_redimensiones(
    image_path: str,
    tamaños: List[Tuple[int, int]] = [(30, 30), (64, 64), (128, 128)]
) -> None:
    """
    Muestra cómo se ve una imagen redimensionada a diferentes resoluciones.

    Args:
        image_path: Ruta a una imagen en escala de grises
        tamaños: Lista de tamaños (ancho, alto) a comparar
    """
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        print(f"[ERROR] No se pudo leer la imagen: {image_path}")
        return

    n = len(tamaños)
    plt.figure(figsize=(4 * n, 4))
    for i, size in enumerate(tamaños):
        resized = cv2.resize(img, size)
        plt.subplot(1, n, i + 1)
        plt.imshow(resized, cmap='gray')
        plt.title(f"{size[0]}×{size[1]}")
        plt.axis('off')
    
    plt.suptitle(f"Comparación de resoluciones para: {Path(image_path).name}", fontsize=14)
    plt.tight_layout()
    plt.show()


visualizar_redimensiones("output_faces/mi_cara.jpg", tamaños=[(30, 30), (64, 64), (128, 128)])
# Out:
# [ERROR] No se pudo leer la imagen: output_faces/mi_cara.jpg
# [ WARN:0@47281.049] global loadsave.cpp:268 findDecoder imread_('output_faces/mi_cara.jpg'): can't open/read file: check file path/integrity
