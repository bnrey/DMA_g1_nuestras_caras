# %% [markdown]
# Proyecto Nuestras Caras

# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %% [markdown]
# Funcion para detectar la cara y recortarla. Usamos la libreria cv2

# %%
def detectar_y_recortar_cara(image_path, output_path, img_size=(30, 30)):
    # Cargar la imagen
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error al cargar la imagen: {image_path}")
        return False
    
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Cargar el clasificador Haar Cascade
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

    # Ajuste de parámetros para mejorar detección
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

    if len(faces) == 0:
        print(f"No se detectó ninguna cara en {image_path}")
        return False
    
    # Seleccionar la cara más grande (por si hay más de una)
    x, y, w, h = max(faces, key=lambda rect: rect[2] * rect[3])

    # Validar tamaño mínimo de la cara detectada
    if w < 30 or h < 30:
        print(f"Cara demasiado pequeña en {image_path}")
        return False

    # Recortar y redimensionar la cara
    face = gray[y:y+h, x:x+w]
    face_resized = cv2.resize(face, img_size)

    # Guardar la imagen procesada
    if not os.path.exists(os.path.dirname(output_path)):
        os.makedirs(os.path.dirname(output_path))
    
    cv2.imwrite(output_path, face_resized)
    print(f"Cara guardada en: {output_path}")
    return True

# %%
def detectar_y_recortar_cara_v2(image_path, output_path, sin_caras_path, img_size=(30, 30)):
    # Cargar la imagen
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error al cargar la imagen: {image_path}")
        return False
    
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Cargar el clasificador Haar Cascade
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

    # Ajuste de parámetros para mejorar detección
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

    if len(faces) == 0:
        print(f"No se detectó ninguna cara en {image_path}")
        
        # Asegurar que la carpeta sin caras exista
        if not os.path.exists(sin_caras_path):
            os.makedirs(sin_caras_path)
        
        # Guardar la imagen sin cara
        no_face_path = os.path.join(sin_caras_path, os.path.basename(image_path))
        cv2.imwrite(no_face_path, img)  # Fixed line
        print(f"Imagen guardada en carpeta sin caras: {no_face_path}")
        return False
    
    # Seleccionar la cara más grande (por si hay más de una)
    x, y, w, h = max(faces, key=lambda rect: rect[2] * rect[3])

    # Validar tamaño mínimo de la cara detectada
    if w < 30 or h < 30:
        print(f"Cara demasiado pequeña en {image_path}")
        return False

    # Recortar y redimensionar la cara
    face = gray[y:y+h, x:x+w]
    face_resized = cv2.resize(face, img_size)

    # Guardar la imagen procesada
    if not os.path.exists(os.path.dirname(output_path)):
        os.makedirs(os.path.dirname(output_path))
    
    cv2.imwrite(output_path, face_resized)
    print(f"Cara guardada en: {output_path}")
    return True

# %%
# Procesar imágenes en una carpeta
def procesar_carpeta(input_folder, output_folder, sin_caras_folder, img_size=(30, 30)):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for subdir, _, files in os.walk(input_folder):
        for file in files:
            input_path = os.path.join(subdir, file)
            output_subdir = os.path.join(output_folder, os.path.basename(subdir))

            if not os.path.exists(output_subdir):
                os.makedirs(output_subdir)

            output_path = os.path.join(output_subdir, file)
            detectar_y_recortar_cara_v2(input_path, output_path, sin_caras_folder, img_size)

# Ejecutar
input_folder = '../Eigenfaces/Eigenfaces'
output_folder = '../Eigenfaces/procesadas2'
sin_caras_folder = '../Eigenfaces/sin_caras'

procesar_carpeta(input_folder, output_folder, sin_caras_folder)
# Out:
# Cara guardada en: ../Eigenfaces/procesadas2/Jorgelina/IMG
2.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Agustín/1742907850091.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Agustín/IMG_20250321_140715339.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Agustín/IMG_8671.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Agustín/20250321_140317.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Agustín/IMG_7613 2.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Agustín/IMG_8670.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Agustín/IMG_6789.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Cristian/IMG_8686.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Cristian/IMG_1097.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Cristian/20250321_170432.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Cristian/20250321_170427.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Cristian/IMG_1096.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Cristian/IMG_7681 2.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Cristian/IMG_6817.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Cristian/IMG_1095.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Cristian/IMG_20250321_170439519.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Cristian/20250321_170423.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Cristian/1742907849783.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Cristian/IMG_8687.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Cristian/IMG_20250321_170437206_HDR.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Cristian/IMG_7681.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Cristian/IMG_4189.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Cristian/IMG_7686 2.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Cristian/IMG_4191.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Cristian/IMG_4190.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Cristian/IMG_20250321_170444007_HDR.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Cristian/IMG_6819.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Cristian/1742907849798.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Cristian/1742907849776.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Cristian/IMG_8685.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Cristian/IMG_6818.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Federico/IMG_7599 2.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Federico/20250321_140309.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Federico/1742907850028.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Federico/IMG_1079.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Federico/IMG_1078.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Federico/IMG_8668.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Federico/IMG_6796.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Federico/IMG_7598 2.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Federico/IMG_6797.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Federico/IMG_4183.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Federico/IMG_4182.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Federico/1742907850046.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Federico/IMG_6795.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Federico/IMG_4181.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Federico/IMG_7598.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Federico/IMG_1077.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Federico/1742907849997.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Federico/IMG_8667.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Federico/20250321_140307.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Federico/IMG_8666.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Federico/20250321_140311.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Guadalupe/IMG_1083.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Guadalupe/20250321_140255.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Guadalupe/IMG_1082.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Guadalupe/IMG_6801.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Guadalupe/IMG_1080.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Guadalupe/IMG_7630.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Guadalupe/IMG_1081.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Guadalupe/IMG_20250321_140746141.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Guadalupe/IMG_20250321_140741716_HDR.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Guadalupe/IMG_6800.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Guadalupe/IMG_8659.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Guadalupe/1742907850076.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Guadalupe/1742907850066.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Guadalupe/IMG_8658.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Guadalupe/IMG_7632 2.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Guadalupe/1742907850056.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Guadalupe/IMG_8657.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Guadalupe/IMG_7630 2.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Guadalupe/IMG_6799.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Guadalupe/IMG_20250321_140744163.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Guadalupe/20250321_140300.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Guadalupe/20250321_140258.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Alejandro/IMG_8690.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Alejandro/IMG_6821.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Alejandro/IMG_20250321_170500203.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Alejandro/IMG_6820.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Alejandro/1742907849769.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Alejandro/1742907849755.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Alejandro/20250321_170445.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Alejandro/IMG_4192.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Alejandro/IMG_7688 2.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Alejandro/IMG_4193.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Alejandro/IMG_7688.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Alejandro/IMG_4194.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Alejandro/20250321_170448.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Alejandro/IMG_7689 2.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Alejandro/IMG_1100.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Alejandro/20250321_170439.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Alejandro/IMG_8688.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Alejandro/IMG_8689.jpeg
# Cara guardada en: ../Eigenfaces/procesadas2/Alejandro/1742907849763.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Alejandro/IMG_1098.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Alejandro/IMG_20250321_170502353.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Alejandro/IMG_1099.JPG
# Cara guardada en: ../Eigenfaces/procesadas2/Alejandro/IMG_20250321_170457147.jpg
# Cara guardada en: ../Eigenfaces/procesadas2/Alejandro/IMG_6822.jpeg

# %% [markdown]
# Cargar las imagenes procesadas

# %%
def cargar_imagenes(input_folder, img_size=(30, 30)):
    X = []
    y = []
    label_dict = {}
    label_counter = 0

    # Recorrer las carpetas de imágenes procesadas
    for subdir, _, files in os.walk(input_folder):
        if not files:
            continue
        if subdir not in label_dict:
            label_dict[subdir] = label_counter
            label_counter += 1

        for file in files:
            img_path = os.path.join(subdir, file)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            if img is not None:
                img_resized = cv2.resize(img, img_size)
                X.append(img_resized.flatten())
                y.append(label_dict[subdir])

    print(f"Se cargaron {len(X)} imágenes.")
    return np.array(X), np.array(y)

# %% [markdown]
# Script para detectar las caras de captura de zoom

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
image_path = 'test/fotos zoom/Captura desde 2025-03-07 14-22-18.png'
img = cv2.imread(image_path)

# Convert to grayscale for face detection
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Load the Haar Cascade classifier for face detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Detect faces
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

# Draw rectangles around detected faces
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

# Convert from BGR to RGB for displaying
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Show the result
plt.figure(figsize=(10, 8))
plt.imshow(img_rgb)
plt.axis('off')
plt.title(f"Detected Faces: {len(faces)}")
plt.show()

# %%
def extract_faces_from_folder(input_folder, output_folder):
    # Create output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # Load Haar Cascade classifier
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

    # Process each image in the folder
    for filename in os.listdir(input_folder):
        image_path = os.path.join(input_folder, filename)

        # Validate if it's an image
        if not filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            print(f"Skipping non-image file: {filename}")
            continue

        # Read and convert to grayscale
        img = cv2.imread(image_path)
        if img is None:
            print(f"Failed to read image: {filename}")
            continue

        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        # Detect faces
        faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

        if len(faces) == 0:
            print(f"No faces detected in {filename}")
            continue
        
        print(f"{len(faces)} face(s) detected in {filename}")

        # Extract and save faces
        for i, (x, y, w, h) in enumerate(faces):
            face = gray[y:y+h, x:x+w]
            face_filename = f"{os.path.splitext(filename)[0]}_face_{i+1}.jpg"
            face_path = os.path.join(output_folder, face_filename)
            cv2.imwrite(face_path, face)
            print(f"Saved face {i+1} from {filename} to {face_path}")

    print("Face extraction completed.")

# Example usage
input_folder = '../Eigenfaces/test/fotos zoom'
output_folder = '../Eigenfaces/test/detectadas'
extract_faces_from_folder(input_folder, output_folder)
# Out:
# 15 face(s) detected in Captura desde 2025-03-15 09-40-47.png
# Saved face 1 from Captura desde 2025-03-15 09-40-47.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-47_face_1.jpg
# Saved face 2 from Captura desde 2025-03-15 09-40-47.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-47_face_2.jpg
# Saved face 3 from Captura desde 2025-03-15 09-40-47.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-47_face_3.jpg
# Saved face 4 from Captura desde 2025-03-15 09-40-47.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-47_face_4.jpg
# Saved face 5 from Captura desde 2025-03-15 09-40-47.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-47_face_5.jpg
# Saved face 6 from Captura desde 2025-03-15 09-40-47.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-47_face_6.jpg
# Saved face 7 from Captura desde 2025-03-15 09-40-47.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-47_face_7.jpg
# Saved face 8 from Captura desde 2025-03-15 09-40-47.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-47_face_8.jpg
# Saved face 9 from Captura desde 2025-03-15 09-40-47.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-47_face_9.jpg
# Saved face 10 from Captura desde 2025-03-15 09-40-47.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-47_face_10.jpg
# Saved face 11 from Captura desde 2025-03-15 09-40-47.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-47_face_11.jpg
# Saved face 12 from Captura desde 2025-03-15 09-40-47.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-47_face_12.jpg
# Saved face 13 from Captura desde 2025-03-15 09-40-47.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-47_face_13.jpg
# Saved face 14 from Captura desde 2025-03-15 09-40-47.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-47_face_14.jpg
# Saved face 15 from Captura desde 2025-03-15 09-40-47.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-47_face_15.jpg
# 14 face(s) detected in Captura desde 2025-03-07 14-50-10.png
# Saved face 1 from Captura desde 2025-03-07 14-50-10.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-10_face_1.jpg
# Saved face 2 from Captura desde 2025-03-07 14-50-10.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-10_face_2.jpg
# Saved face 3 from Captura desde 2025-03-07 14-50-10.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-10_face_3.jpg
# Saved face 4 from Captura desde 2025-03-07 14-50-10.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-10_face_4.jpg
# Saved face 5 from Captura desde 2025-03-07 14-50-10.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-10_face_5.jpg
# Saved face 6 from Captura desde 2025-03-07 14-50-10.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-10_face_6.jpg
# Saved face 7 from Captura desde 2025-03-07 14-50-10.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-10_face_7.jpg
# Saved face 8 from Captura desde 2025-03-07 14-50-10.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-10_face_8.jpg
# Saved face 9 from Captura desde 2025-03-07 14-50-10.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-10_face_9.jpg
# Saved face 10 from Captura desde 2025-03-07 14-50-10.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-10_face_10.jpg
# Saved face 11 from Captura desde 2025-03-07 14-50-10.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-10_face_11.jpg
# Saved face 12 from Captura desde 2025-03-07 14-50-10.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-10_face_12.jpg
# Saved face 13 from Captura desde 2025-03-07 14-50-10.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-10_face_13.jpg
# Saved face 14 from Captura desde 2025-03-07 14-50-10.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-10_face_14.jpg
# 13 face(s) detected in Captura desde 2025-03-07 14-50-05.png
# Saved face 1 from Captura desde 2025-03-07 14-50-05.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-05_face_1.jpg
# Saved face 2 from Captura desde 2025-03-07 14-50-05.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-05_face_2.jpg
# Saved face 3 from Captura desde 2025-03-07 14-50-05.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-05_face_3.jpg
# Saved face 4 from Captura desde 2025-03-07 14-50-05.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-05_face_4.jpg
# Saved face 5 from Captura desde 2025-03-07 14-50-05.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-05_face_5.jpg
# Saved face 6 from Captura desde 2025-03-07 14-50-05.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-05_face_6.jpg
# Saved face 7 from Captura desde 2025-03-07 14-50-05.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-05_face_7.jpg
# Saved face 8 from Captura desde 2025-03-07 14-50-05.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-05_face_8.jpg
# Saved face 9 from Captura desde 2025-03-07 14-50-05.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-05_face_9.jpg
# Saved face 10 from Captura desde 2025-03-07 14-50-05.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-05_face_10.jpg
# Saved face 11 from Captura desde 2025-03-07 14-50-05.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-05_face_11.jpg
# Saved face 12 from Captura desde 2025-03-07 14-50-05.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-05_face_12.jpg
# Saved face 13 from Captura desde 2025-03-07 14-50-05.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-07 14-50-05_face_13.jpg
# 15 face(s) detected in Captura desde 2025-03-15 09-40-42.png
# Saved face 1 from Captura desde 2025-03-15 09-40-42.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-42_face_1.jpg
# Saved face 2 from Captura desde 2025-03-15 09-40-42.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-42_face_2.jpg
# Saved face 3 from Captura desde 2025-03-15 09-40-42.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-42_face_3.jpg
# Saved face 4 from Captura desde 2025-03-15 09-40-42.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-42_face_4.jpg
# Saved face 5 from Captura desde 2025-03-15 09-40-42.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-42_face_5.jpg
# Saved face 6 from Captura desde 2025-03-15 09-40-42.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-42_face_6.jpg
# Saved face 7 from Captura desde 2025-03-15 09-40-42.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-42_face_7.jpg
# Saved face 8 from Captura desde 2025-03-15 09-40-42.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-42_face_8.jpg
# Saved face 9 from Captura desde 2025-03-15 09-40-42.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-42_face_9.jpg
# Saved face 10 from Captura desde 2025-03-15 09-40-42.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-42_face_10.jpg
# Saved face 11 from Captura desde 2025-03-15 09-40-42.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-42_face_11.jpg
# Saved face 12 from Captura desde 2025-03-15 09-40-42.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-42_face_12.jpg
# Saved face 13 from Captura desde 2025-03-15 09-40-42.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-42_face_13.jpg
# Saved face 14 from Captura desde 2025-03-15 09-40-42.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-42_face_14.jpg
# Saved face 15 from Captura desde 2025-03-15 09-40-42.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-42_face_15.jpg
# 14 face(s) detected in Captura desde 2025-03-15 09-40-18.png
# Saved face 1 from Captura desde 2025-03-15 09-40-18.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-18_face_1.jpg
# Saved face 2 from Captura desde 2025-03-15 09-40-18.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-18_face_2.jpg
# Saved face 3 from Captura desde 2025-03-15 09-40-18.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-18_face_3.jpg
# Saved face 4 from Captura desde 2025-03-15 09-40-18.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-18_face_4.jpg
# Saved face 5 from Captura desde 2025-03-15 09-40-18.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-18_face_5.jpg
# Saved face 6 from Captura desde 2025-03-15 09-40-18.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-18_face_6.jpg
# Saved face 7 from Captura desde 2025-03-15 09-40-18.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-18_face_7.jpg
# Saved face 8 from Captura desde 2025-03-15 09-40-18.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-18_face_8.jpg
# Saved face 9 from Captura desde 2025-03-15 09-40-18.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-18_face_9.jpg
# Saved face 10 from Captura desde 2025-03-15 09-40-18.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-18_face_10.jpg
# Saved face 11 from Captura desde 2025-03-15 09-40-18.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-18_face_11.jpg
# Saved face 12 from Captura desde 2025-03-15 09-40-18.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-18_face_12.jpg
# Saved face 13 from Captura desde 2025-03-15 09-40-18.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-18_face_13.jpg
# Saved face 14 from Captura desde 2025-03-15 09-40-18.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-40-18_face_14.jpg
# 13 face(s) detected in Captura desde 2025-03-15 09-39-54.png
# Saved face 1 from Captura desde 2025-03-15 09-39-54.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-39-54_face_1.jpg
# Saved face 2 from Captura desde 2025-03-15 09-39-54.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-39-54_face_2.jpg
# Saved face 3 from Captura desde 2025-03-15 09-39-54.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-39-54_face_3.jpg
# Saved face 4 from Captura desde 2025-03-15 09-39-54.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-39-54_face_4.jpg
# Saved face 5 from Captura desde 2025-03-15 09-39-54.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-39-54_face_5.jpg
# Saved face 6 from Captura desde 2025-03-15 09-39-54.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-39-54_face_6.jpg
# Saved face 7 from Captura desde 2025-03-15 09-39-54.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-39-54_face_7.jpg
# Saved face 8 from Captura desde 2025-03-15 09-39-54.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-39-54_face_8.jpg
# Saved face 9 from Captura desde 2025-03-15 09-39-54.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-39-54_face_9.jpg
# Saved face 10 from Captura desde 2025-03-15 09-39-54.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-39-54_face_10.jpg
# Saved face 11 from Captura desde 2025-03-15 09-39-54.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-39-54_face_11.jpg
# Saved face 12 from Captura desde 2025-03-15 09-39-54.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-39-54_face_12.jpg
# Saved face 13 from Captura desde 2025-03-15 09-39-54.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-39-54_face_13.jpg
# 12 face(s) detected in Captura desde 2025-03-08 13-13-18.png
# Saved face 1 from Captura desde 2025-03-08 13-13-18.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-08 13-13-18_face_1.jpg
# Saved face 2 from Captura desde 2025-03-08 13-13-18.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-08 13-13-18_face_2.jpg
# Saved face 3 from Captura desde 2025-03-08 13-13-18.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-08 13-13-18_face
from Captura desde 2025-03-15 09-57-53.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-57-53_face_11.jpg
# Saved face 12 from Captura desde 2025-03-15 09-57-53.png to ../Eigenfaces/test/detectadas/Captura desde 2025-03-15 09-57-53_face_12.jpg
# Face extraction completed.

# %%
# Create a directory to save the extracted faces
output_folder = '../Eigenfaces/test'
os.makedirs(output_folder, exist_ok=True)

# Extract and save each detected face
face_images = []
for i, (x, y, w, h) in enumerate(faces):
    face = img[y:y+h, x:x+w]
    face_path = os.path.join(output_folder, f"face_{i+1}.jpg")
    cv2.imwrite(face_path, face)
    face_images.append(face_path)

face_images

# %%
# Cargar imágenes procesadas
input_folder = '../Eigenfaces/procesadas2'
X, y = cargar_imagenes(input_folder)

# Estandarizar las imágenes
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Aplicar PCA
pca = PCA(n_components=0.95)  # Mantener el 95% de la varianza
X_pca = pca.fit_transform(X_scaled)

print(f"Dimensiones originales: {X.shape[1]}")
print(f"Dimensiones después de PCA: {X_pca.shape[1]}")
# Out:
# Se cargaron 271 imágenes.
# Dimensiones originales: 900
# Dimensiones después de PCA: 141

# %%
# Visualizar la varianza acumulada
plt.figure(figsize=(8, 5))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Número de Componentes')
plt.ylabel('Varianza Acumulada')
plt.grid(True)
plt.title('Varianza Explicada por PCA')
plt.show()

# %% [markdown]
# Cara promedio

# %%
mean_face = np.mean(X, axis=0)

# Convertir a imagen 2D
mean_face_image = mean_face.reshape(30, 30)

# Visualizar la cara promedio
plt.figure(figsize=(6, 6))
plt.imshow(mean_face_image, cmap='gray')
plt.title("Cara Promedio")
plt.axis('off')
plt.show()

# %%
k = 5  # Número de componentes principales a visualizar
fig, axs = plt.subplots(1, k, figsize=(5, 3))
fig.suptitle(f"Primeras {k} componentes principales (Eigenfaces)", fontsize=14)
for i in range(k):
    eigenface = pca.components_[i].reshape(30, 30)
    axs[i].imshow(eigenface, cmap='gray')
    axs[i].set_title(f"PC{i+1}")
    axs[i].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# Otra forma

# %%
def cargar_imagenes(directorio):
    """
    Carga imágenes de un directorio, conviertiéndolas a escala de grises y redimensionándolas.
    
    Parámetros:
    - directorio: Ruta al directorio con las imágenes de entrenamiento
    
    Retorna:
    - imagenes: Lista de imágenes procesadas
    - etiquetas: Lista de etiquetas correspondientes
    - nombres: Lista de nombres de personas
    """
    imagenes = []
    etiquetas = []
    nombres = []
    
    # Iterar sobre subdirectorios (cada subdirectorio representa una persona)
    for nombre in os.listdir(directorio):
        ruta_persona = os.path.join(directorio, nombre)
        
        # Verificar que sea un directorio
        if os.path.isdir(ruta_persona):
            for archivo in os.listdir(ruta_persona):
                ruta_imagen = os.path.join(ruta_persona, archivo)
                
                # Cargar imagen
                img = cv2.imread(ruta_imagen)
                if img is not None:
                    # Convertir a escala de grises
                    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                    # Redimensionar
                    gray_resized = cv2.resize(gray, (64, 64))
                    
                    imagenes.append(gray_resized)
                    etiquetas.append(len(nombres))
            
            nombres.append(nombre)
    
    return np.array(imagenes), np.array(etiquetas), nombres
